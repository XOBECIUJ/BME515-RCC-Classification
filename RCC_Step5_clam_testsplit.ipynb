# %% [markdown]
# # RCC Subtyping — Step 5: CLAM-SB / CLAM-MB Training with alternative split for validation
# ### BME 515 Final Project
# Train CLAM single-branch (SB) and multi-branch (MB) on the 2048-dim ResNet50 features produced in Step 2.
#
# Classes: Benign, Chromophobe (KICH), Clearcell (ccRCC), Oncocytoma, Papillary (KIRP) — 5-way slide-level classification.

# %% [markdown]
# ## 0) Setup and Environment
# This cell imports all required libraries, sets project paths, creates output folders, fixes random seeds for reproducibility, and selects the compute device (MPS, CUDA, or CPU).
#
# Expected output: the selected device printed to confirm where training/inference will run.

# %%
import os, json, random
from pathlib import Path
from collections import Counter

import numpy as np
import pandas as pd
import h5py
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (accuracy_score, f1_score, roc_auc_score,
                             confusion_matrix, classification_report)
import matplotlib.pyplot as plt

BASE_DIR   = Path(r'C:\Users\raphi\Documents\BME515-RCC-Classification')
FEATURE_DIR = BASE_DIR / 'features' / 'features'
META_PATH  = BASE_DIR / 'MetaData_Release_1.1.csv'
CKPT_DIR   = BASE_DIR / 'checkpoints'
RESULT_DIR = BASE_DIR / 'results_testsplit'
CKPT_DIR.mkdir(exist_ok=True)
RESULT_DIR.mkdir(exist_ok=True)

SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)

device = torch.device('mps' if torch.backends.mps.is_available()
                      else 'cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)
# Out:
# device: cuda

# %%
import torch
print('torch:', torch.__version__)
print('cuda build:', torch.version.cuda)
print('available:', torch.cuda.is_available())
print('device:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'N/A')
x = torch.randn(1000, 1000).cuda()
y = x @ x
print('GPU compute works:', y.shape, y.device)
# Out:
# torch: 2.12.0.dev20260408+cu128
# cuda build: 12.8
# available: True
# device: NVIDIA GeForce RTX 5060 Laptop GPU
# GPU compute works: torch.Size([1000, 1000]) cuda:0

# %% [markdown]
# ### 1. Build label table

# %%
CLASSES = ['Benign', 'Chromophobe', 'Clearcell', 'Oncocytoma', 'Papillary']
label2idx = {c: i for i, c in enumerate(CLASSES)}
idx2label = {i: c for c, i in label2idx.items()}
N_CLASSES = len(CLASSES)

meta = pd.read_csv(META_PATH)
meta['slide_id'] = meta['File Name'].str.replace('.png', '', regex=False)

available = sorted(p.stem for p in FEATURE_DIR.glob('*.h5'))
df = meta[meta['slide_id'].isin(available)].copy()
df['label'] = df['Diagnosis'].map(label2idx)
df = df.dropna(subset=['label']).reset_index(drop=True)
df['label'] = df['label'].astype(int)

print(f'usable slides: {len(df)}')
print(df['Diagnosis'].value_counts())
# Out:
# usable slides: 484
# Diagnosis
# Clearcell      310
# Papillary       80
# Oncocytoma      42
# Benign          29
# Chromophobe     23
# Name: count, dtype: int64

# %% [markdown]
# ## 1.1) Data Integrity Checks
# This block prints metadata schema and feature-file stats to verify that metadata IDs align with available feature files.
#
# Use it to diagnose path problems, naming mismatches, or missing features before training.

# %%
# Check metadata
print('=== Metadata ===')
print('rows:', len(meta))
print('columns:', list(meta.columns))
print('first 3 File Names:', meta['File Name'].head(3).tolist())
print('first 3 slide_ids:', meta['slide_id'].head(3).tolist())

# Check feature files
print('\n=== Feature files ===')
print('FEATURE_DIR:', FEATURE_DIR)
print('exists:', FEATURE_DIR.exists())
h5_files = list(FEATURE_DIR.glob('*.h5'))
print('number of .h5 files:', len(h5_files))
if h5_files:
    print('first 3 .h5 filenames:', [p.name for p in h5_files[:3]])
    print('first 3 .h5 stems:', [p.stem for p in h5_files[:3]])
# Out:
# === Metadata ===
# rows: 563
# columns: ['File Name', 'Diagnosis', 'Slide Type', 'Data Split', 'slide_id']
# first 3 File Names: ['DHMC_0001.png', 'DHMC_0002.png', 'DHMC_0003.png']
# first 3 slide_ids: ['DHMC_0001', 'DHMC_0002', 'DHMC_0003']
#
# === Feature files ===
# FEATURE_DIR: C:\Users\raphi\Documents\BME515-RCC-Classification\features\features
# exists: True
# number of .h5 files: 484
# first 3 .h5 filenames: ['DHMC_0001.h5', 'DHMC_0002.h5', 'DHMC_0003.h5']
# first 3 .h5 stems: ['DHMC_0001', 'DHMC_0002', 'DHMC_0003']

# %% [markdown]
# ## 2) Dataset Class (Slide-Level Bags)
# Defines a PyTorch Dataset where each sample is one slide represented by a variable-length bag of patch features.
#
# Returns per item:
# 1. Feature tensor with shape [N, 2048] (or reshaped equivalent).
# 2. Integer class label.
# 3. Slide ID string.
#
# Note: this loader currently reads `.pt` files inside the class body. If your final pipeline uses `.h5`, this cell should be updated accordingly.

# %%
class SlideFeatureDataset(Dataset):
    """One item = one slide. Returns (features [N,2048], label int, slide_id)."""
    def __init__(self, df, feature_dir):
        self.df = df.reset_index(drop=True)
        self.feature_dir = Path(feature_dir)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, i):
        row = self.df.iloc[i]
        h5_path = self.feature_dir / f"{row.slide_id}.h5"

        if not h5_path.exists():
            raise FileNotFoundError(f"Missing feature file: {h5_path}")

        with h5py.File(h5_path, "r") as f:
            # common dataset keys used in feature files
            for k in ["features", "feats", "x", "embeddings"]:
                if k in f:
                    arr = f[k][:]
                    break
            else:
                keys = list(f.keys())
                if len(keys) == 1:
                    arr = f[keys[0]][:]
                else:
                    raise KeyError(f"No feature dataset key found in {h5_path}. Keys: {keys}")

        feats = torch.from_numpy(np.asarray(arr))
        if feats.ndim == 3:
             feats = feats.view(feats.size(0), -1)
        elif feats.ndim != 2:
            feats = feats.reshape(feats.shape[0], -1)

        return feats.float(), int(row.label), row.slide_id

# %% [markdown]
# ## 3) Stratified Data Split and Dataset Objects
# Splits data into train/validation/test sets with label stratification to preserve class balance across splits.
#
# It also saves split CSV files for reproducibility and instantiates PyTorch Dataset objects for each split.
#
# Expected output: sample counts and class distributions for train/val/test.

# %%
from sklearn.model_selection import train_test_split

# 60/20/20 stratified split
train_df, temp_df = train_test_split(df, test_size=0.40,
                                     stratify=df['label'], random_state=SEED)
val_df, test_df = train_test_split(temp_df, test_size=0.50,
                                   stratify=temp_df['label'], random_state=SEED)

print(f'train: {len(train_df)}  val: {len(val_df)}  test: {len(test_df)}')
for name, sub in [('train', train_df), ('val', val_df), ('test', test_df)]:
    print(f'  {name}:', dict(sub['Diagnosis'].value_counts()))

for name, sub in [('train', train_df), ('val', val_df), ('test', test_df)]:
    sub[['slide_id','Diagnosis','label']].to_csv(RESULT_DIR / f'split_{name}.csv', index=False)

train_ds = SlideFeatureDataset(train_df, FEATURE_DIR)
val_ds   = SlideFeatureDataset(val_df,   FEATURE_DIR)
test_ds  = SlideFeatureDataset(test_df,  FEATURE_DIR)
# Out:
# train: 290  val: 97  test: 97
#   train: {'Clearcell': np.int64(186), 'Papillary': np.int64(48), 'Oncocytoma': np.int64(25), 'Benign': np.int64(17), 'Chromophobe': np.int64(14)}
#   val: {'Clearcell': np.int64(62), 'Papillary': np.int64(16), 'Oncocytoma': np.int64(9), 'Benign': np.int64(6), 'Chromophobe': np.int64(4)}
#   test: {'Clearcell': np.int64(62), 'Papillary': np.int64(16), 'Oncocytoma': np.int64(8), 'Benign': np.int64(6), 'Chromophobe': np.int64(5)}

# %% [markdown]
# ## 4) CLAM Model Architecture (Gated Attention + SB/MB)
# This block defines the core neural network used for slide-level RCC subtype prediction.
#
# Components:
# 1. `GatedAttention`: computes attention scores over patch embeddings using tanh-sigmoid gating.
# 2. `CLAM`: unified implementation for single-branch (SB) and multi-branch (MB) modes.
# 3. Instance-level heads: support clustering-style supervision via top-k and bottom-k patch sampling.
#
# Forward-pass flow:
# 1. Project patch features from 2048 to hidden dimension.
# 2. Compute attention scores across patches.
# 3. Normalize attention with softmax.
# 4. Aggregate patch features into slide representation.
# 5. Predict slide-level class probabilities.
# 6. Optionally compute instance-level loss during training.
#
# Outputs from `forward(...)`:
# 1. `logits`: raw class scores for the slide.
# 2. `y_prob`: softmax probabilities.
# 3. `y_hat`: predicted class index.
# 4. `A_raw`: pre-softmax attention scores.
# 5. `inst_loss`: instance-level auxiliary loss.

# %%
class GatedAttention(nn.Module):
    """Gated attention from Ilse et al. 2018 / CLAM."""
    def __init__(self, in_dim, hidden=256, n_branches=1, dropout=0.25):
        super().__init__()
        self.attn_a = nn.Sequential(nn.Linear(in_dim, hidden), nn.Tanh(), nn.Dropout(dropout))
        self.attn_b = nn.Sequential(nn.Linear(in_dim, hidden), nn.Sigmoid(), nn.Dropout(dropout))
        self.attn_c = nn.Linear(hidden, n_branches)

    def forward(self, h):
        # h: [N, D]
        a = self.attn_a(h) * self.attn_b(h)        # [N, hidden]
        return self.attn_c(a)                      # [N, n_branches]


class CLAM(nn.Module):
    """Unified CLAM module supporting SB (n_branches=1) and MB (n_branches=n_classes)."""
    def __init__(self, in_dim=2048, hidden=512, attn_hidden=256,
                 n_classes=5, k_sample=8, multi_branch=False, dropout=0.25):
        super().__init__()
        self.n_classes = n_classes
        self.k_sample = k_sample
        self.multi_branch = multi_branch
        n_branches = n_classes if multi_branch else 1

        # patch-level projection
        self.fc = nn.Sequential(nn.Linear(in_dim, hidden), nn.ReLU(), nn.Dropout(dropout))

        self.attention = GatedAttention(hidden, attn_hidden, n_branches, dropout)

        # slide classifier
        if multi_branch:
            # one classifier head per class (binary: class vs not-class)
            self.classifiers = nn.ModuleList([nn.Linear(hidden, 1) for _ in range(n_classes)])
        else:
            self.classifier = nn.Linear(hidden, n_classes)

        # instance classifiers for clustering loss (one per class)
        self.instance_classifiers = nn.ModuleList([nn.Linear(hidden, 2) for _ in range(n_classes)])

    # --- clustering / instance helpers -----------------------------------
    @staticmethod
    def _create_labels(length, value, device):
        return torch.full((length,), value, dtype=torch.long, device=device)

    def _inst_eval(self, attn_scores, h, classifier):
        """Attend-class: top-k positives, bottom-k negatives."""
        k = min(self.k_sample, h.size(0) // 2)
        if k < 1: return None, None
        top_p_ids = torch.topk(attn_scores, k)[1]
        top_n_ids = torch.topk(-attn_scores, k)[1]
        top_p = h[top_p_ids]
        top_n = h[top_n_ids]
        p_labels = self._create_labels(k, 1, h.device)
        n_labels = self._create_labels(k, 0, h.device)
        all_inst = torch.cat([top_p, top_n], dim=0)
        all_lbl  = torch.cat([p_labels, n_labels], dim=0)
        logits = classifier(all_inst)
        return logits, all_lbl

    def _inst_eval_out(self, attn_scores, h, classifier):
        """Non-attend-class: top-k are pseudo-negatives."""
        k = min(self.k_sample, h.size(0) // 2)
        if k < 1: return None, None
        top_p_ids = torch.topk(attn_scores, k)[1]
        top_p = h[top_p_ids]
        p_labels = self._create_labels(k, 0, h.device)
        logits = classifier(top_p)
        return logits, p_labels

    # --- forward ----------------------------------------------------------
    def forward(self, h, label=None, instance_eval=True):
        # h: [N, in_dim]
        h = self.fc(h)                             # [N, hidden]
        A = self.attention(h)                      # [N, n_branches]
        A = torch.transpose(A, 1, 0)               # [n_branches, N]
        A_raw = A
        A = F.softmax(A, dim=1)                    # softmax over patches

        # instance-level clustering loss (training only, if label provided)
        inst_loss = torch.tensor(0., device=h.device)
        inst_count = 0
        if instance_eval and label is not None:
            onehot = F.one_hot(torch.tensor(label, device=h.device),
                               num_classes=self.n_classes).long()
            # for SB we only have 1 attention branch → use it for class=label
            for c in range(self.n_classes):
                scores = A[c if self.multi_branch else 0]
                cls = self.instance_classifiers[c]
                if onehot[c] == 1:
                    logits, lbl = self._inst_eval(scores, h, cls)
                else:
                    if not self.multi_branch:
                        continue  # SB only runs out-of-class sampling when MB
                    logits, lbl = self._inst_eval_out(scores, h, cls)
                if logits is None: continue
                inst_loss = inst_loss + F.cross_entropy(logits, lbl)
                inst_count += 1
            if inst_count > 0:
                inst_loss = inst_loss / inst_count

        # slide-level aggregation
        if self.multi_branch:
            # M: [n_classes, hidden] — one embedding per class
            M = A @ h                              # [n_classes, hidden]
            logits = torch.cat([self.classifiers[c](M[c:c+1])
                                for c in range(self.n_classes)], dim=1)  # [1, n_classes]
        else:
            M = A @ h                              # [1, hidden]
            logits = self.classifier(M)            # [1, n_classes]

        y_prob = F.softmax(logits, dim=1)
        y_hat  = torch.argmax(logits, dim=1)
        return logits, y_prob, y_hat, A_raw, inst_loss

# %% [markdown]
# ## 5) Loss, Collation, and Evaluation Utilities
# Defines utility functions used during optimization and validation/testing:
# 1. `mil_collate`: custom collate function for variable-length slide bags.
# 2. `compute_class_weights`: inverse-frequency class weighting for cross-entropy.
# 3. `evaluate`: computes loss, accuracy, macro-F1, and stores predictions/probabilities.
#
# These utilities ensure stable mini-batch handling and consistent metric tracking across splits.

# %%
def compute_class_weights(df, n_classes):
    counts = np.zeros(n_classes)
    for lab in df['label'].values:
        counts[int(lab)] += 1
    # inverse frequency, normalized
    w = counts.sum() / (n_classes * np.maximum(counts, 1))
    return torch.tensor(w, dtype=torch.float32)

class_weights = compute_class_weights(train_df, N_CLASSES).to(device)
print('class weights:', dict(zip(CLASSES, class_weights.cpu().numpy().round(3))))
# Out:
# class weights: {'Benign': np.float32(3.412), 'Chromophobe': np.float32(4.143), 'Clearcell': np.float32(0.312), 'Oncocytoma': np.float32(2.32), 'Papillary': np.float32(1.208)}

# %% [markdown]
# ## 6) Training Configuration and Loop
# Sets training hyperparameters and trains both CLAM variants with early stopping on validation macro-F1.
#
# Training behavior:
# 1. Builds model, optimizer, and weighted CE loss.
# 2. Combines bag-level and instance-level losses (`total = bag + lambda_inst * inst`).
# 3. Saves the best checkpoint for each model to `checkpoints/`.
# 4. Logs per-epoch metrics to `results/*_history.csv`.

# %%
def train_one_epoch(model, loader, optimizer, ce_loss, bag_weight=0.7):
    model.train()
    total_loss, total_bag, total_inst, correct, n = 0, 0, 0, 0, 0
    for feats, label, _ in loader:
        feats = feats.squeeze(0).to(device)
        label_t = torch.tensor([label], dtype=torch.long, device=device) \
                  if not torch.is_tensor(label) else label.to(device)
        optimizer.zero_grad()
        logits, _, y_hat, _, inst_loss = model(feats, label=int(label_t.item()),
                                                instance_eval=True)
        bag_loss = ce_loss(logits, label_t)
        loss = bag_weight * bag_loss + (1 - bag_weight) * inst_loss
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

        total_loss += loss.item(); total_bag += bag_loss.item()
        total_inst += float(inst_loss.item() if torch.is_tensor(inst_loss) else inst_loss)
        correct += (y_hat.item() == int(label_t.item()))
        n += 1
    return total_loss/n, total_bag/n, total_inst/n, correct/n

@torch.no_grad()
def evaluate(model, loader, ce_loss):
    model.eval()
    y_true, y_pred, y_prob, slide_ids = [], [], [], []
    total_loss, n = 0, 0
    for feats, label, sid in loader:
        feats = feats.squeeze(0).to(device)
        label_t = torch.tensor([label], dtype=torch.long, device=device) \
                  if not torch.is_tensor(label) else label.to(device)
        logits, prob, y_hat, _, _ = model(feats, label=None, instance_eval=False)
        loss = ce_loss(logits, label_t)
        total_loss += loss.item(); n += 1
        y_true.append(int(label_t.item()))
        y_pred.append(int(y_hat.item()))
        y_prob.append(prob.cpu().numpy().ravel())
        slide_ids.append(sid[0] if isinstance(sid, (list, tuple)) else sid)
    y_prob = np.stack(y_prob, axis=0)
    return {
        'loss': total_loss/n,
        'acc': accuracy_score(y_true, y_pred),
        'f1_macro': f1_score(y_true, y_pred, average='macro', zero_division=0),
        'y_true': y_true, 'y_pred': y_pred, 'y_prob': y_prob,
        'slide_ids': slide_ids
    }

# %% [markdown]
# ### 6.1) Launch SB and MB Training Runs
# Executes the training loop for:
# 1. `clam_sb` (single-branch CLAM).
# 2. `clam_mb` (multi-branch CLAM).
#
# Expected output: epoch-by-epoch train/validation metrics and saved best checkpoints.

# %%
def run_training(model_name, multi_branch, epochs=50, lr=2e-4, wd=1e-5,
                 bag_weight=0.7, patience=10):
    print(f'\n=== Training {model_name} ===')
    model = CLAM(in_dim=2048, hidden=512, attn_hidden=256,
                 n_classes=N_CLASSES, k_sample=8,
                 multi_branch=multi_branch).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=wd)
    sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=epochs)
    ce = nn.CrossEntropyLoss(weight=class_weights)

    train_loader = DataLoader(train_ds, batch_size=1, shuffle=True)
    val_loader   = DataLoader(val_ds,   batch_size=1, shuffle=False)

    history = []
    best_val_f1, best_epoch, bad = -1, 0, 0
    best_path = CKPT_DIR / f'{model_name}_best.pt'

    for ep in range(1, epochs+1):
        tr_loss, tr_bag, tr_inst, tr_acc = train_one_epoch(model, train_loader, opt, ce, bag_weight)
        val = evaluate(model, val_loader, ce)
        sched.step()

        history.append({
            'epoch': ep,
            'train_loss': tr_loss,
            'train_bag_loss': tr_bag,
            'train_inst_loss': tr_inst,
            'train_acc': tr_acc,
            'val_loss': val['loss'],
            'val_acc': val['acc'],
            'val_f1': val['f1_macro']
        })

        print(f'[{model_name}] ep {ep:02d} | '
              f'train loss {tr_loss:.3f} (bag {tr_bag:.3f}, inst {tr_inst:.3f}) acc {tr_acc:.3f} | '
              f'val loss {val["loss"]:.3f} acc {val["acc"]:.3f} f1 {val["f1_macro"]:.3f}')

        if val['f1_macro'] > best_val_f1:
            best_val_f1, best_epoch, bad = val['f1_macro'], ep, 0
            torch.save(model.state_dict(), best_path)
        else:
            bad += 1
            if bad >= patience:
                print(f'early stop at ep {ep} (best ep {best_epoch}, val f1 {best_val_f1:.3f})')
                break

    pd.DataFrame(history).to_csv(RESULT_DIR / f'{model_name}_history.csv', index=False)
    return model, best_path, history

sb_model, sb_ckpt, sb_hist = run_training('clam_sb', multi_branch=False, epochs=50)
mb_model, mb_ckpt, mb_hist = run_training('clam_mb', multi_branch=True,  epochs=50)
# Out:
# === Training clam_sb ===
# [clam_sb] ep 01 | train loss 1.159 (bag 1.540, inst 0.269) acc 0.638 | val loss 1.452 acc 0.639 f1 0.156
# [clam_sb] ep 02 | train loss 0.940 (bag 1.260, inst 0.194) acc 0.686 | val loss 1.197 acc 0.732 f1 0.309
# [clam_sb] ep 03 | train loss 0.796 (bag 1.091, inst 0.105) acc 0.724 | val loss 1.368 acc 0.742 f1 0.316
# [clam_sb] ep 04 | train loss 0.722 (bag 0.988, inst 0.099) acc 0.759 | val loss 1.755 acc 0.732 f1 0.309
# [clam_sb] ep 05 | train loss 0.633 (bag 0.873, inst 0.074) acc 0.769 | val loss 1.325 acc 0.732 f1 0.312
# [clam_sb] ep 06 | train loss 0.553 (bag 0.767, inst 0.054) acc 0.779 | val loss 1.083 acc 0.753 f1 0.424
# [clam_sb] ep 07 | train loss 0.499 (bag 0.695, inst 0.042) acc 0.807 | val loss 1.409 acc 0.773 f1 0.424
# [clam_sb] ep 08 | train loss 0.452 (bag 0.628, inst 0.042) acc 0.817 | val loss 1.431 acc 0.763 f1 0.420
# [clam_sb] ep 09 | train loss 0.398 (bag 0.558, inst 0.027) acc 0.828 | val loss 1.213 acc 0.804 f1 0.497
# [clam_sb] ep 10 | train loss 0.398 (bag 0.553, inst 0.039) acc 0.848 | val loss 1.079 acc 0.742 f1 0.492
# [clam_sb] ep 11 | train loss 0.313 (bag 0.433, inst 0.035) acc 0.869 | val loss 1.147 acc 0.732 f1 0.473
# [clam_sb] ep 12 | train loss 0.313 (bag 0.434, inst 0.029) acc 0.872 | val loss 1.334 acc 0.773 f1 0.517
# [clam_sb] ep 13 | train loss 0.274 (bag 0.382, inst 0.021) acc 0.883 | val loss 1.259 acc 0.742 f1 0.514
# [clam_sb] ep 14 | train loss 0.278 (bag 0.391, inst 0.016) acc 0.886 | val loss 0.918 acc 0.794 f1 0.545
# [clam_sb] ep 15 | train loss 0.242 (bag 0.338, inst 0.018) acc 0.897 | val loss 0.951 acc 0.835 f1 0.612
# [clam_sb] ep 16 | train loss 0.193 (bag 0.272, inst 0.009) acc 0.907 | val loss 1.019 acc 0.814 f1 0.571
# [clam_sb] ep 17 | train loss 0.171 (bag 0.240, inst 0.010) acc 0.917 | val loss 1.195 acc 0.814 f1 0.585
# [clam_sb] ep 18 | train loss 0.157 (bag 0.219, inst 0.013) acc 0.931 | val loss 1.299 acc 0.825 f1 0.594
# [clam_sb] ep 19 | train loss 0.155 (bag 0.216, inst 0.013) acc 0.931 | val loss 1.212 acc 0.835 f1 0.604
# [clam_sb] ep 20 | train loss 0.127 (bag 0.172, inst 0.020) acc 0.948 | val loss 1.010 acc 0.794 f1 0.597
# [clam_sb] ep 21 | train loss 0.107 (bag 0.149, inst 0.010) acc 0.948 | val loss 1.202 acc 0.825 f1 0.583
# [clam_sb] ep 22 | train loss 0.129 (bag 0.182, inst 0.006) acc 0.941 | val loss 1.336 acc 0.845 f1 0.692
# [clam_sb] ep 23 | train loss 0.091 (bag 0.128, inst 0.006) acc 0.952 | val loss 1.155 acc 0.835 f1 0.653
# [clam_sb] ep 24 | train loss 0.084 (bag 0.117, inst 0.006) acc 0.955 | val loss 1.157 acc 0.814 f1 0.656
# [clam_sb] ep 25 | train loss 0.099 (bag 0.138, inst 0.007) acc 0.952 | val loss 1.275 acc 0.835 f1 0.652
# [clam_sb] ep 26 | train loss 0.075 (bag 0.106, inst 0.004) acc 0.962 | val loss 1.125 acc 0.835 f1 0.687
# [clam_sb] ep 27 | train loss 0.061 (bag 0.085, inst 0.004) acc 0.969 | val loss 1.283 acc 0.835 f1 0.679
# [clam_sb] ep 28 | train loss 0.062 (bag 0.083, inst 0.012) acc 0.976 | val loss 1.169 acc 0.804 f1 0.640
# [clam_sb] ep 29 | train loss 0.077 (bag 0.106, inst 0.008) acc 0.966 | val loss 1.287 acc 0.814 f1 0.631
# [clam_sb] ep 30 | train loss 0.079 (bag 0.110, inst 0.008) acc 0.976 | val loss 1.418 acc 0.856 f1 0.716
# [clam_sb] ep 31 | train loss 0.062 (bag 0.086, inst 0.003) acc 0.976 | val loss 1.203 acc 0.814 f1 0.677
# [clam_sb] ep 32 | train loss 0.048 (bag 0.066, inst 0.003) acc 0.979 | val loss 1.147 acc 0.825 f1 0.675
# [clam_sb] ep 33 | train loss 0.038 (bag 0.051, inst 0.007) acc 0.983 | val loss 1.358 acc 0.835 f1 0.713
# [clam_sb] ep 34 | train loss 0.049 (bag 0.067, inst 0.008) acc 0.976 | val loss 1.334 acc 0.845 f1 0.734
# [clam_sb] ep 35 | train loss 0.045 (bag 0.062, inst 0.004) acc 0.976 | val loss 1.227 acc 0.825 f1 0.679
# [clam_sb] ep 36 | train loss 0.041 (bag 0.056, inst 0.004) acc 0.986 | val loss 1.209 acc 0.814 f1 0.672
# [clam_sb] ep 37 | train loss 0.034 (bag 0.046, inst 0.007) acc 0.983 | val loss 1.278 acc 0.814 f1 0.657
# [clam_sb] ep 38 | train loss 0.040 (bag 0.055, inst 0.005) acc 0.976 | val loss 1.236 acc 0.825 f1 0.709
# [clam_sb] ep 39 | train loss 0.040 (bag 0.054, inst 0.006) acc 0.976 | val loss 1.398 acc 0.835 f1 0.706
# [clam_sb] ep 40 | train loss 0.027 (bag 0.036, inst 0.006) acc 0.986 | val loss 1.308 acc 0.825 f1 0.684
# [clam_sb] ep 41 | train loss 0.039 (bag 0.054, inst 0.005) acc 0.983 | val loss 1.323 acc 0.825 f1 0.684
# [clam_sb] ep 42 | train loss 0.014 (bag 0.019, inst 0.003) acc 0.993 | val loss 1.315 acc 0.814 f1 0.657
# [clam_sb] ep 43 | train loss 0.026 (bag 0.034, inst 0.008) acc 0.990 | val loss 1.311 acc 0.814 f1 0.657
# [clam_sb] ep 44 | train loss 0.044 (bag 0.059, inst 0.009) acc 0.979 | val loss 1.343 acc 0.814 f1 0.657
# early stop at ep 44 (best ep 34, val f1 0.734)
#
# === Training clam_mb ===
# [clam_mb] ep 01 | train loss 1.274 (bag 1.658, inst 0.375) acc 0.631 | val loss 1.307 acc 0.639 f1 0.156
# [clam_mb] ep 02 | train loss 0.910 (bag 1.163, inst 0.317) acc 0.672 | val loss 1.093 acc 0.732 f1 0.305
# [clam_mb] ep 03 | train loss 0.764 (bag 0.982, inst 0.254) acc 0.748 | val loss 1.243 acc 0.670 f1 0.272
# [clam_mb] ep 04 | train loss 0.696 (bag 0.892, inst 0.239) acc 0.769 | val loss 0.927 acc 0.711 f1 0.294
# [clam_mb] ep 05 | train loss 0.717 (bag 0.908, inst 0.272) acc 0.779 | val loss 0.997 acc 0.753 f1 0.322
# [clam_mb] ep 06 | train loss 0.567 (bag 0.710, inst 0.234) acc 0.793 | val loss 1.230 acc 0.639 f1 0.259
# [clam_mb] ep 07 | train loss 0.532 (bag 0.661, inst 0.230) acc 0.824 | val loss 0.909 acc 0.742 f1 0.457
# [clam_mb] ep 08 | train loss 0.490 (bag 0.608, inst 0.215) acc 0.814 | val loss 0.999 acc 0.722 f1 0.449
# [clam_mb] ep 09 | train loss 0.444 (bag 0.546, inst 0.206) acc 0.838 | val loss 0.971 acc 0.814 f1 0.551
# [clam_mb] ep 10 | train loss 0.417 (bag 0.513, inst 0.192) acc 0.841 | val loss 0.694 acc 0.814 f1 0.567
# [clam_mb] ep 11 | train loss 0.300 (bag 0.357, inst 0.167) acc 0.869 | val loss 1.083 acc 0.804 f1 0.507
# [clam_mb] ep 12 | train loss 0.317 (bag 0.378, inst 0.174) acc 0.876 | val loss 0.917 acc 0.773 f1 0.575
# [clam_mb] ep 13 | train loss 0.252 (bag 0.293, inst 0.155) acc 0.900 | val loss 0.885 acc 0.804 f1 0.664
# [clam_mb] ep 14 | train loss 0.261 (bag 0.312, inst 0.141) acc 0.914 | val loss 1.106 acc 0.845 f1 0.604
# [clam_mb] ep 15 | train loss 0.170 (bag 0.189, inst 0.127) acc 0.938 | val loss 0.988 acc 0.835 f1 0.624
# [clam_mb] ep 16 | train loss 0.156 (bag 0.170, inst 0.121) acc 0.945 | val loss 1.036 acc 0.845 f1 0.662
# [clam_mb] ep 17 | train loss 0.152 (bag 0.167, inst 0.117) acc 0.938 | val loss 0.834 acc 0.856 f1 0.737
# [clam_mb] ep 18 | train loss 0.131 (bag 0.145, inst 0.100) acc 0.952 | val loss 1.148 acc 0.814 f1 0.594
# [clam_mb] ep 19 | train loss 0.119 (bag 0.123, inst 0.109) acc 0.955 | val loss 1.275 acc 0.835 f1 0.639
# [clam_mb] ep 20 | train loss 0.087 (bag 0.084, inst 0.093) acc 0.966 | val loss 1.050 acc 0.866 f1 0.762
# [clam_mb] ep 21 | train loss 0.095 (bag 0.094, inst 0.097) acc 0.969 | val loss 1.201 acc 0.845 f1 0.655
# [clam_mb] ep 22 | train loss 0.101 (bag 0.104, inst 0.093) acc 0.972 | val loss 1.148 acc 0.835 f1 0.647
# [clam_mb] ep 23 | train loss 0.078 (bag 0.075, inst 0.085) acc 0.969 | val loss 1.145 acc 0.887 f1 0.763
# [clam_mb] ep 24 | train loss 0.060 (bag 0.052, inst 0.079) acc 0.986 | val loss 1.249 acc 0.845 f1 0.655
# [clam_mb] ep 25 | train loss 0.058 (bag 0.048, inst 0.082) acc 0.983 | val loss 1.189 acc 0.856 f1 0.710
# [clam_mb] ep 26 | train loss 0.068 (bag 0.063, inst 0.081) acc 0.983 | val loss 1.010 acc 0.866 f1 0.725
# [clam_mb] ep 27 | train loss 0.048 (bag 0.035, inst 0.078) acc 0.993 | val loss 1.122 acc 0.856 f1 0.688
# [clam_mb] ep 28 | train loss 0.055 (bag 0.044, inst 0.078) acc 0.990 | val loss 1.016 acc 0.887 f1 0.789
# [clam_mb] ep 29 | train loss 0.043 (bag 0.031, inst 0.070) acc 0.993 | val loss 1.092 acc 0.856 f1 0.741
# [clam_mb] ep 30 | train loss 0.042 (bag 0.028, inst 0.073) acc 0.993 | val loss 1.150 acc 0.845 f1 0.697
# [clam_mb] ep 31 | train loss 0.039 (bag 0.027, inst 0.067) acc 0.990 | val loss 1.136 acc 0.856 f1 0.733
# [clam_mb] ep 32 | train loss 0.042 (bag 0.032, inst 0.066) acc 0.993 | val loss 1.122 acc 0.866 f1 0.726
# [clam_mb] ep 33 | train loss 0.039 (bag 0.028, inst 0.066) acc 0.993 | val loss 1.215 acc 0.876 f1 0.743
# [clam_mb] ep 34 | train loss 0.038 (bag 0.026, inst 0.065) acc 0.993 | val loss 1.251 acc 0.897 f1 0.797
# [clam_mb] ep 35 | train loss 0.038 (bag 0.026, inst 0.064) acc 0.993 | val loss 1.179 acc 0.866 f1 0.728
# [clam_mb] ep 36 | train loss 0.037 (bag 0.026, inst 0.061) acc 0.993 | val loss 1.196 acc 0.876 f1 0.764
# [clam_mb] ep 37 | train loss 0.036 (bag 0.025, inst 0.061) acc 0.993 | val loss 1.182 acc 0.866 f1 0.725
# [clam_mb] ep 38 | train loss 0.035 (bag 0.024, inst 0.061) acc 0.993 | val loss 1.140 acc 0.866 f1 0.728
# [clam_mb] ep 39 | train loss 0.033 (bag 0.021, inst 0.059) acc 0.993 | val loss 1.169 acc 0.866 f1 0.716
# [clam_mb] ep 40 | train loss 0.036 (bag 0.026, inst 0.057) acc 0.993 | val loss 1.226 acc 0.866 f1 0.726
# [clam_mb] ep 41 | train loss 0.035 (bag 0.025, inst 0.059) acc 0.993 | val loss 1.197 acc 0.866 f1 0.736
# [clam_mb] ep 42 | train loss 0.030 (bag 0.019, inst 0.056) acc 0.993 | val loss 1.176 acc 0.866 f1 0.728
# [clam_mb] ep 43 | train loss 0.029 (bag 0.017, inst 0.057) acc 0.993 | val loss 1.160 acc 0.866 f1 0.716
# [clam_mb] ep 44 | train loss 0.030 (bag 0.018, inst 0.059) acc 0.993 | val loss 1.180 acc 0.866 f1 0.716
# early stop at ep 44 (best ep 34, val f1 0.797)

# %% [markdown]
# ### 6.2) ABMIL training
#
# As an MIL model baseline

# %%
# ===== ABMIL =====
# ABMIL = gated attention + classifier, no instance clustering loss.
# Achieved by setting bag_weight=1.0 (zeros out instance loss) on the
# single-branch CLAM architecture.

abmil_model, abmil_ckpt, abmil_hist = run_training(
    'abmil', multi_branch=False, epochs=50, bag_weight=1.0
)
# Out:
# === Training abmil ===
# [abmil] ep 01 | train loss 1.748 (bag 1.748, inst 0.792) acc 0.638 | val loss 1.147 acc 0.639 f1 0.156
# [abmil] ep 02 | train loss 1.200 (bag 1.200, inst 0.814) acc 0.724 | val loss 1.255 acc 0.649 f1 0.268
# [abmil] ep 03 | train loss 1.087 (bag 1.087, inst 0.720) acc 0.755 | val loss 1.308 acc 0.649 f1 0.265
# [abmil] ep 04 | train loss 1.050 (bag 1.050, inst 0.738) acc 0.769 | val loss 1.502 acc 0.722 f1 0.302
# [abmil] ep 05 | train loss 0.863 (bag 0.863, inst 0.746) acc 0.772 | val loss 1.444 acc 0.649 f1 0.266
# [abmil] ep 06 | train loss 0.895 (bag 0.895, inst 0.766) acc 0.752 | val loss 1.688 acc 0.742 f1 0.316
# [abmil] ep 07 | train loss 0.709 (bag 0.709, inst 0.780) acc 0.793 | val loss 1.081 acc 0.732 f1 0.420
# [abmil] ep 08 | train loss 0.651 (bag 0.651, inst 0.831) acc 0.807 | val loss 1.343 acc 0.732 f1 0.305
# [abmil] ep 09 | train loss 0.622 (bag 0.622, inst 0.880) acc 0.834 | val loss 0.832 acc 0.763 f1 0.527
# [abmil] ep 10 | train loss 0.534 (bag 0.534, inst 0.924) acc 0.838 | val loss 1.107 acc 0.794 f1 0.497
# [abmil] ep 11 | train loss 0.435 (bag 0.435, inst 0.941) acc 0.866 | val loss 1.141 acc 0.835 f1 0.613
# [abmil] ep 12 | train loss 0.480 (bag 0.480, inst 0.960) acc 0.855 | val loss 1.068 acc 0.814 f1 0.587
# [abmil] ep 13 | train loss 0.351 (bag 0.351, inst 0.982) acc 0.890 | val loss 0.925 acc 0.814 f1 0.586
# [abmil] ep 14 | train loss 0.415 (bag 0.415, inst 0.968) acc 0.886 | val loss 0.944 acc 0.804 f1 0.543
# [abmil] ep 15 | train loss 0.329 (bag 0.329, inst 1.003) acc 0.893 | val loss 0.875 acc 0.825 f1 0.573
# [abmil] ep 16 | train loss 0.249 (bag 0.249, inst 0.967) acc 0.907 | val loss 1.256 acc 0.825 f1 0.572
# [abmil] ep 17 | train loss 0.267 (bag 0.267, inst 0.969) acc 0.921 | val loss 1.149 acc 0.825 f1 0.594
# [abmil] ep 18 | train loss 0.185 (bag 0.185, inst 0.968) acc 0.941 | val loss 1.008 acc 0.835 f1 0.612
# [abmil] ep 19 | train loss 0.248 (bag 0.248, inst 0.969) acc 0.928 | val loss 1.133 acc 0.835 f1 0.605
# [abmil] ep 20 | train loss 0.272 (bag 0.272, inst 0.995) acc 0.924 | val loss 1.115 acc 0.835 f1 0.622
# [abmil] ep 21 | train loss 0.194 (bag 0.194, inst 0.987) acc 0.955 | val loss 1.249 acc 0.814 f1 0.554
# [abmil] ep 22 | train loss 0.155 (bag 0.155, inst 0.977) acc 0.955 | val loss 1.191 acc 0.825 f1 0.571
# [abmil] ep 23 | train loss 0.192 (bag 0.192, inst 0.976) acc 0.941 | val loss 1.115 acc 0.835 f1 0.595
# [abmil] ep 24 | train loss 0.142 (bag 0.142, inst 0.951) acc 0.959 | val loss 1.328 acc 0.794 f1 0.584
# [abmil] ep 25 | train loss 0.149 (bag 0.149, inst 0.929) acc 0.948 | val loss 1.124 acc 0.835 f1 0.605
# [abmil] ep 26 | train loss 0.110 (bag 0.110, inst 0.925) acc 0.952 | val loss 1.525 acc 0.845 f1 0.666
# [abmil] ep 27 | train loss 0.137 (bag 0.137, inst 0.932) acc 0.966 | val loss 1.154 acc 0.845 f1 0.659
# [abmil] ep 28 | train loss 0.108 (bag 0.108, inst 0.975) acc 0.966 | val loss 1.114 acc 0.845 f1 0.658
# [abmil] ep 29 | train loss 0.090 (bag 0.090, inst 0.992) acc 0.969 | val loss 1.481 acc 0.856 f1 0.708
# [abmil] ep 30 | train loss 0.110 (bag 0.110, inst 0.990) acc 0.969 | val loss 1.390 acc 0.845 f1 0.657
# [abmil] ep 31 | train loss 0.088 (bag 0.088, inst 0.962) acc 0.972 | val loss 1.422 acc 0.845 f1 0.666
# [abmil] ep 32 | train loss 0.064 (bag 0.064, inst 0.970) acc 0.976 | val loss 1.300 acc 0.856 f1 0.683
# [abmil] ep 33 | train loss 0.083 (bag 0.083, inst 0.962) acc 0.976 | val loss 1.313 acc 0.856 f1 0.678
# [abmil] ep 34 | train loss 0.075 (bag 0.075, inst 0.951) acc 0.979 | val loss 1.393 acc 0.835 f1 0.673
# [abmil] ep 35 | train loss 0.049 (bag 0.049, inst 0.934) acc 0.983 | val loss 1.327 acc 0.856 f1 0.671
# [abmil] ep 36 | train loss 0.062 (bag 0.062, inst 0.961) acc 0.979 | val loss 1.336 acc 0.845 f1 0.680
# [abmil] ep 37 | train loss 0.062 (bag 0.062, inst 0.966) acc 0.979 | val loss 1.319 acc 0.845 f1 0.676
# [abmil] ep 38 | train loss 0.050 (bag 0.050, inst 0.944) acc 0.979 | val loss 1.339 acc 0.856 f1 0.698
# [abmil] ep 39 | train loss 0.051 (bag 0.051, inst 0.974) acc 0.979 | val loss 1.340 acc 0.856 f1 0.698
# early stop at ep 39 (best ep 29, val f1 0.708)

# %% [markdown]
# ## 7) Test Evaluation and Result Export
# Loads each model's best checkpoint and evaluates on the held-out test split.
#
# Saved artifacts per model in `results/`:
# 1. `*_test_predictions.csv`: per-slide predictions and class probabilities.
# 2. `*_test_summary.json`: aggregate test metrics (accuracy, macro-F1, AUC).
#
# The printed report includes macro metrics, class-wise precision/recall/F1, and the confusion matrix.

# %%
def test_and_save(model_name, multi_branch):
    model = CLAM(in_dim=2048, hidden=512, attn_hidden=256,
                 n_classes=N_CLASSES, k_sample=8,
                 multi_branch=multi_branch).to(device)
    model.load_state_dict(torch.load(CKPT_DIR / f'{model_name}_best.pt', map_location=device))
    test_loader = DataLoader(test_ds, batch_size=1, shuffle=False)
    res = evaluate(model, test_loader, nn.CrossEntropyLoss(weight=class_weights))

    # multi-class AUC (ovr, weighted) — handle missing classes gracefully
    try:
        auc = roc_auc_score(res['y_true'], res['y_prob'], multi_class='ovr',
                            average='weighted', labels=list(range(N_CLASSES)))
    except Exception as e:
        auc = float('nan'); print('AUC warn:', e)

    print(f'\n{model_name} TEST: acc {res["acc"]:.3f}  f1 {res["f1_macro"]:.3f}  auc {auc:.3f}')
    print(classification_report(res['y_true'], res['y_pred'],
                                target_names=CLASSES, zero_division=0))
    print('confusion matrix (rows=true, cols=pred):')
    print(pd.DataFrame(confusion_matrix(res['y_true'], res['y_pred'],
                                        labels=list(range(N_CLASSES))),
                       index=CLASSES, columns=CLASSES))

    # save per-slide predictions for analysis notebook
    out = pd.DataFrame({
        'slide_id': res['slide_ids'],
        'true_label': [idx2label[i] for i in res['y_true']],
        'pred_label': [idx2label[i] for i in res['y_pred']],
        'correct': [a==b for a,b in zip(res['y_true'], res['y_pred'])],
        'confidence': res['y_prob'].max(axis=1),
    })
    for c, name in idx2label.items():
        out[f'prob_{name}'] = res['y_prob'][:, c]
    out.to_csv(RESULT_DIR / f'{model_name}_test_predictions.csv', index=False)

    with open(RESULT_DIR / f'{model_name}_test_summary.json', 'w') as f:
        json.dump({'acc': res['acc'], 'f1_macro': res['f1_macro'], 'auc': auc}, f, indent=2)
    return res, auc

abmil_res, abmil_auc = test_and_save('abmil', multi_branch=False)
sb_res, sb_auc = test_and_save('clam_sb', multi_branch=False)
mb_res, mb_auc = test_and_save('clam_mb', multi_branch=True)
# Out:
# abmil TEST: acc 0.856  f1 0.683  auc 0.952
#               precision    recall  f1-score   support
#
#       Benign       0.67      0.67      0.67         6
#  Chromophobe       0.56      1.00      0.71         5
#    Clearcell       0.91      0.95      0.93        62
#   Oncocytoma       0.50      0.12      0.20         8
#    Papillary       0.93      0.88      0.90        16
#
#     accuracy                           0.86        97
#    macro avg       0.71      0.72      0.68        97
# weighted avg       0.85      0.86      0.84        97
#
# confusion matrix (rows=true, cols=pred):
#              Benign  Chromophobe  Clearcell  Oncocytoma  Papillary
# Benign            4            0          2           0          0
# Chromophobe       0            5          0           0          0
# Clearcell         1            0         59           1          1
# Oncocytoma        1            4          2           1          0
# Papillary         0            0          2           0         14
#
# clam_sb TEST: acc 0.825  f1 0.610  auc 0.952
#               precision    recall  f1-score   support
#
#       Benign       0.67      1.00      0.80         6
#  Chromophobe       0.43      0.60      0.50         5
#    Clearcell       0.93      0.92      0.93        62
#   Oncocytoma       0.00      0.00      0.00         8
#    Papillary       0.78      0.88      0.82        16
#
#     accuracy                           0.82        97
#    macro avg       0.56      0.68      0.61        97
# weighted avg       0.79      0.82      0.80        97
#
# confusion matrix (rows=true, cols=pred):
#              Benign  Chromophobe  Clearcell  Oncocytoma  Papillary
# Benign            6            0          0           0          0
# Chromophobe       1            3          0           1          0
# Clearcell         1            0         57           0          4
# Oncocytoma        1            4          3           0          0
# Papillary         0            0          1           1         14
#
# clam_mb TEST: acc 0.804  f1 0.576  auc 0.950
#               precision    recall  f1-score   support
#
#       Benign       0.50      0.33      0.40         6
#  Chromophobe       0.50      0.60      0.55         5
#    Clearcell       0.88      0.94      0.91        62
#   Oncocytoma       0.20      0.12      0.15         8
#    Papillary       0.88      0.88      0.88        16
#
#     accuracy                           0.80        97
#    macro avg       0.59      0.57      0.58        97
# weighted avg       0.78      0.80      0.79        97
#
# confusion matrix (rows=true, cols=pred):
#              Benign  Chromophobe  Clearcell  Oncocytoma  Papillary
# Benign            2            0          3           1          0
# Chromophobe       0            3          1           1          0
# Clearcell         1            0         58           1          2
# Oncocytoma        1            3          3           1          0
# Papillary         0            0          1           1         14

# %% [markdown]
# ## 8) Training Curves and Run Summary
# This block visualizes optimization behavior for CLAM-SB and CLAM-MB using the saved in-memory training histories.
#
# It plots:
# 1. Train vs validation loss across epochs.
# 2. Validation macro-F1 across epochs.
#
# It also exports `training_curves.png` to the results folder and prints a completion message with the output path.

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))
for name, hist in [('ABMIL', abmil_hist), ('CLAM-SB', sb_hist), ('CLAM-MB', mb_hist)]:
    h = pd.DataFrame(hist)
    axes[0].plot(h.epoch, h.train_loss, label=f'{name} train')
    axes[0].plot(h.epoch, h.val_loss,   label=f'{name} val', linestyle='--')
    axes[1].plot(h.epoch, h.val_f1,     label=f'{name} val F1')
axes[0].set_title('Loss'); axes[0].set_xlabel('epoch'); axes[0].legend()
axes[1].set_title('Val macro-F1'); axes[1].set_xlabel('epoch'); axes[1].legend()
plt.tight_layout()
plt.savefig(RESULT_DIR / 'training_curves.png', dpi=150)
plt.show()

print('Training complete. Predictions saved to:', RESULT_DIR)
# Out:
# Training complete. Predictions saved to: C:\Users\raphi\Documents\BME515-RCC-Classification\results_testsplit
